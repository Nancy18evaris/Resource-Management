# %%
import pandas as pd
import numpy as np

# %%
rajasthan_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18_0800_NIC_FINAL_STATE_RAJASTHAN-2011.csv", encoding='ISO-8859-1')

# %%
arunachal_pradesh_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18_1200_NIC_FINAL_STATE_ARUNACHAL_PRADESH-2011.csv", encoding='ISO-8859-1')

# %%
manipur_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18_1400_NIC_FINAL_STATE_MANIPUR-2011.csv", encoding='ISO-8859-1')

# %%
mizoram_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18_1500_NIC_FINAL_STATE_MIZORAM-2011.csv", encoding='ISO-8859-1')

# %%
west_bengal_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18_1900_NIC_FINAL_STATE_WEST_BENGAL-2011.csv", encoding='ISO-8859-1')

# %%
delhi_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_0700_NIC_FINAL_STATE_NCT_OF_DELHI-2011.csv" , encoding='ISO-8859-1')

# %%
tripura_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_1600_NIC_FINAL_STATE_TRIPURA-2011.csv" , encoding='ISO-8859-1')

# %%
jharkhand_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_2000_NIC_FINAL_STATE_JHARKHAND-2011.csv" , encoding='ISO-8859-1')

# %%
gujarat_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_2400_NIC_FINAL_STATE_GUJARAT-2011.csv" , encoding='ISO-8859-1')

# %%
maharashtra_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_2700_NIC_FINAL_STATE_MAHARASHTRA-2011.csv" , encoding='ISO-8859-1')

# %%
karnataka_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_2900_NIC_FINAL_STATE_KARNATAKA-2011.csv" , encoding='ISO-8859-1')

# %%
goa_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_3000_NIC_FINAL_STATE_GOA-2011.csv" , encoding='ISO-8859-1')

# %%
kerala_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_3200_NIC_FINAL_STATE_KERALA-2011.csv" , encoding='ISO-8859-1')

# %%
tamil_nadu_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_3300_NIC_FINAL_STATE_TAMIL_NADU-2011.csv" , encoding='ISO-8859-1')

# %%
puducherry_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18sc_3400_NIC_FINAL_STATE_PUDUCHERRY-2011.csv" , encoding='ISO-8859-1')

# %%
himachal_pradesh_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_0200_NIC_FINAL_STATE_HIMACHAL_PRADESH-2011.csv" , encoding='ISO-8859-1')

# %%
uttarkhand_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_0500_NIC_FINAL_STATE_UTTARAKHAND-2011.csv" , encoding='ISO-8859-1')

# %%
uttar_pradesh_df= pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_0900_NIC_FINAL_STATE_UTTAR_PRADESH-2011.csv" , encoding='ISO-8859-1')

# %%
bihar_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_1000_NIC_FINAL_STATE_BIHAR-2011.csv" , encoding='ISO-8859-1')

# %%
sikkim_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_1100_NIC_FINAL_STATE_SIKKIM-2011.csv" , encoding='ISO-8859-1')

# %%
nagaland_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_1300_NIC_FINAL_STATE_NAGALAND-2011.csv" , encoding='ISO-8859-1')

# %%
assam_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_1800_NIC_FINAL_STATE_ASSAM-2011.csv" , encoding='ISO-8859-1')

# %%
odisha_df = pd.read_csv(r"M:\ResourceManagement\New folder\DDW_B18st_2100_NIC_FINAL_STATE_ODISHA-2011.csv" , encoding='ISO-8859-1')

# %%
states_df = pd.concat([rajasthan_df, arunachal_pradesh_df, manipur_df, mizoram_df, west_bengal_df, delhi_df, tripura_df, jharkhand_df, gujarat_df,
                        maharashtra_df, karnataka_df, goa_df, kerala_df, tamil_nadu_df, puducherry_df, himachal_pradesh_df, uttarkhand_df, uttar_pradesh_df, 
                        bihar_df, sikkim_df, nagaland_df, assam_df, odisha_df     
                        ])
print(states_df.shape)
pd.set_option('display.max_columns', None)
states_df
# Out:
# (195145, 25)
#       State Code District Code           India/States Division Group  Class  \
# 0            `08          `000      STATE - RAJASTHAN      `00  `000  `0000
# 1            `08          `000      STATE - RAJASTHAN      `01  `000  `0000
# 2            `08          `000      STATE - RAJASTHAN      `01  `011  `0000
# 3            `08          `000      STATE - RAJASTHAN      `01  `011  `0111
# 4            `08          `000      STATE - RAJASTHAN      `01  `011  `0112
# ...          ...           ...                    ...      ...   ...    ...
# 12042        `21          `399  District - Malkangiri      `99  `000  `0000
# 12043        `21          `399  District - Malkangiri      `99  `991  `0000
# 12044        `21          `399  District - Malkangiri      `99  `991  `9910
# 12045        `21          `399  District - Malkangiri      `99  `992  `0000
# 12046        `21          `399  District - Malkangiri      `99  `992  `9920
#
# ...

# %%
states_df.to_csv("after_merged.csv") # converting df to csv
